# %%
import pandas as pd
import numpy as np
import json

df = pd.read_csv('../data/tt_asignaciones_samp.csv')

# %%
df.head().T
# Out:
#                                                                     0  \
# genero                                                      MASCULINO
# etnia                                                         Mestizo
# cod_parroquia_reside                                          10113.0
# cod_canton_reside                                               101.0
# cod_prov_reside                                                   1.0
# pos_id                                                       16516144
# pos_nota                                                        784.0
# pos_prioridad                                                     1.0
# ies_id                                                             48
# nombre_institucion                              UNIVERSIDAD DE CUENCA
# provincia                                                       AZUAY
# canton                                                         CUENCA
# parroquia             CUENCA, CABECERA CANTONAL Y CAPITAL PROVINCIAL.
# car_id                                                           4910
# carrera                                                  GASTRONOMIA
# area                                                        SERVICIOS
# modalidad                                                  PRESENCIAL
# acepta_cupo                                                         1
# ofa_id                                                          98329
# discapacidad                                                       NO
# asa_beca                                                            0
# cod_final                                                  9352450110
# periodo                                                            18
#
#                                                                      1  \
# genero                                                       MASCULINO
# etnia                                                        IndÃ­gena
# cod_parroquia_reside                                           60104.0
# cod_canton_reside                                                601.0
# cod_prov_reside                                                    6.0
# pos_id                                                        17825859
# pos_nota                                                         774.0
# pos_prioridad                                                      1.0
# ies_id                                                              58
# nombre_institucion                      UNIVERSIDAD ESTATAL DE BOLIVAR
# provincia                                                      BOLIVAR
# canton                                                        GUARANDA
# parroquia             GUARANDA, CABECERA CANTONAL Y CAPITAL PROVINCIAL
# car_id                                                            4908
# carrera                                                 MERCADOTECNIA
# area                                                    ADMINISTRACION
# modalidad                                                   PRESENCIAL
# acepta_cupo                                                          1
# ofa_id                                                          103172
# discapacidad                                                        NO
# asa_beca                                                             0
# cod_final                                                   2185420629
# periodo                                                             18
#
#                                                                   2  \
# genero                                                    MASCULINO
# etnia                                                     Mestizo/a
# cod_parroquia_reside                                       170256.0
# cod_canton_reside                                            1702.0
# cod_prov_reside                                                17.0
# pos_id                                                     25735501
# pos_nota                                                      759.0
# pos_prioridad                                                   1.0
# ies_id                                                          804
# nombre_institucion             UNIVERSIDAD REGIONAL AMAZONICA IKIAM
# provincia                                                      NAPO
# canton                                                         TENA
# parroquia                                                      TENA
# car_id                                                         5335
# carrera                                               BIOTECNOLOGIA
# area                  CIENCIAS NATURALES, MATEMATICAS Y ESTADISTICA
# modalidad                                                PRESENCIAL
# acepta_cupo                                                       1
# ofa_id                                                       167503
# discapacidad                                                     NO
# asa_beca                                                          0
# cod_final                                                9250821701
# periodo                                                          21
#
#                                                                       3  \
# genero                                                         FEMENINO
# etnia                                                         Mestizo/a
# cod_parroquia_reside                                           220350.0
# cod_canton_reside                                                2203.0
# cod_prov_reside                                                    22.0
# pos_id                                                         28452649
# pos_nota                                                          841.0
# pos_prioridad                                                       1.0
# ies_id                                                              877
# nombre_institucion    INSTITUTO TECNOLÓGICO SUPERIOR GENERAL ELOY AL...
# provincia                                                      ORELLANA
# canton                                            LA JOYA DE LOS SACHAS
# parroquia                                         LA JOYA DE LOS SACHAS
# car_id                                                             7147
# carrera                           TECNOLOGIA SUPERIOR EN ADMINISTRACION
# area                                                     ADMINISTRACION
# modalidad                                                    PRESENCIAL
# acepta_cupo                                                           1
# ofa_id                                                           177308
# discapacidad                                                         NO
# asa_beca                                                              0
# cod_final                                                    2746992201
# periodo                                                              22
#
#                                                                       4
# genero                                                         FEMENINO
# etnia                                                         Mestizo/a
# cod_parroquia_reside                                           170164.0
# cod_canton_reside                                                1701.0
# cod_prov_reside                                                    17.0
# pos_id                                                         24917400
# pos_nota                                                          760.0
# pos_prioridad                                                       2.0
# ies_id                                                               46
# nombre_institucion                      UNIVERSIDAD CENTRAL DEL ECUADOR
# provincia                                                     PICHINCHA
# canton                                  DISTRITO METROPOLITANO DE QUITO
# parroquia             QUITO DISTRITO METROPOLITANO, CABECERA CANTONA...
# car_id                                                             7363
# carrera                                                 ARTES PLASTICAS
# area                                                ARTES Y HUMANIDADES
# modalidad                                                    PRESENCIAL
# acepta_cupo                                                           2
# ofa_id                                                           162934
# discapacidad                                                         NO
# asa_beca                                                              0
# cod_final                                                    2520001738
# periodo                                                              21

# %% [markdown]
# #### Duplicates

# %%
def get_shape(df):
    print(df.shape)
    return df
(df
 .pipe(get_shape)
 .drop_duplicates()
 .pipe(get_shape)
 .sample()
)
# Out:
# (178252, 23)
# (178244, 23)
#           genero    etnia  cod_parroquia_reside  cod_canton_reside  \
# 154723  FEMENINO  Mestizo              230106.0             2301.0
#
#         cod_prov_reside    pos_id  pos_nota  pos_prioridad  ies_id  \
# 154723             23.0  14907405     781.0            2.0      71
#
#                         nombre_institucion  ... car_id  \
# 154723  UNIVERSIDAD NACIONAL DE CHIMBORAZO  ...   4458
#
#                           carrera            area   modalidad acepta_cupo  \
# 154723  CONTABILIDAD Y AUDITORIA   ADMINISTRACION  PRESENCIAL           0
#
#        ofa_id discapacidad  asa_beca   cod_final periodo
# 154723  82937           NO         0  1751872365      17
#
# [1 rows x 23 columns]

# %% [markdown]
# ### Understanding our data

# %% [markdown]
# #### Missing Values

# %%
(df
 .isna()
 .groupby(df.periodo)
 .mean()
 .style
 .format(lambda fl: f'{fl * 100:.2f} %')
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_911d6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >genero</th>
#       <th class="col_heading level0 col1" >etnia</th>
#       <th class="col_heading level0 col2" >cod_parroquia_reside</th>
#       <th class="col_heading level0 col3" >cod_canton_reside</th>
#       <th class="col_heading level0 col4" >cod_prov_reside</th>
#       <th class="col_heading level0 col5" >pos_id</th>
#       <th class="col_heading level0 col6" >pos_nota</th>
#       <th class="col_heading level0 col7" >pos_prioridad</th>
#       <th class="col_heading level0 col8" >ies_id</th>
#       <th class="col_heading level0 col9" >nombre_institucion</th>
#       <th class="col_heading level0 col10" >provincia</th>
#       <th class="col_heading level0 col11" >canton</th>
#       <th class="col_heading level0 col12" >parroquia</th>
#       <th class="col_heading level0 col13" >car_id</th>
#       <th class="col_heading level0 col14" >carrera</th>
#       <th class="col_heading level0 col15" >area</th>
#       <th class="col_heading level0 col16" >modalidad</th>
#       <th class="col_heading level0 col17" >acepta_cupo</th>
#       <th class="col_heading level0 col18" >ofa_id</th>
#       <th class="col_heading level0 col19" >discapacidad</th>
#       <th class="col_heading level0 col20" >asa_beca</th>
#       <th class="col_heading level0 col21" >cod_final</th>
#       <th class="col_heading level0 col22" >periodo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >periodo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_911d6_level0_row0" class="row_heading level0 row0" >17</th>
#       <td id="T_911d6_row0_col0" class="data row0 col0" >2.99 %</td>
#       <td id="T_911d6_row0_col1" class="data row0 col1" >4.68 %</td>
#       <td id="T_911d6_row0_col2" class="data row0 col2" >3.41 %</td>
#       <td id="T_911d6_row0_col3" class="data row0 col3" >3.41 %</td>
#       <td id="T_911d6_row0_col4" class="data row0 col4" >3.41 %</td>
#       <td id="T_911d6_row0_col5" class="data row0 col5" >0.00 %</td>
#       <td id="T_911d6_row0_col6" class="data row0 col6" >0.00 %</td>
#       <td id="T_911d6_row0_col7" class="data row0 col7" >0.00 %</td>
#       <td id="T_911d6_row0_col8" class="data row0 col8" >0.00 %</td>
#       <td id="T_911d6_row0_col9" class="data row0 col9" >0.00 %</td>
#       <td id="T_911d6_row0_col10" class="data row0 col10" >0.00 %</td>
#       <td id="T_911d6_row0_col11" class="data row0 col11" >0.00 %</td>
#       <td id="T_911d6_row0_col12" class="data row0 col12" >0.00 %</td>
#       <td id="T_911d6_row0_col13" class="data row0 col13" >0.00 %</td>
#       <td id="T_911d6_row0_col14" class="data row0 col14" >0.00 %</td>
#       <td id="T_911d6_row0_col15" class="data row0 col15" >0.00 %</td>
#       <td id="T_911d6_row0_col16" class="data row0 col16" >0.00 %</td>
#       <td id="T_911d6_row0_col17" class="data row0 col17" >0.00 %</td>
#       <td id="T_911d6_row0_col18" class="data row0 col18" >0.00 %</td>
#       <td id="T_911d6_row0_col19" class="data row0 col19" >0.00 %</td>
#       <td id="T_911d6_row0_col20" class="data row0 col20" >0.00 %</td>
#       <td id="T_911d6_row0_col21" class="data row0 col21" >0.00 %</td>
#       <td id="T_911d6_row0_col22" class="data row0 col22" >0.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_911d6_level0_row1" class="row_heading level0 row1" >18</th>
#       <td id="T_911d6_row1_col0" class="data row1 col0" >2.15 %</td>
#       <td id="T_911d6_row1_col1" class="data row1 col1" >4.58 %</td>
#       <td id="T_911d6_row1_col2" class="data row1 col2" >3.69 %</td>
#       <td id="T_911d6_row1_col3" class="data row1 col3" >3.69 %</td>
#       <td id="T_911d6_row1_col4" class="data row1 col4" >3.69 %</td>
#       <td id="T_911d6_row1_col5" class="data row1 col5" >0.00 %</td>
#       <td id="T_911d6_row1_col6" class="data row1 col6" >0.00 %</td>
#       <td id="T_911d6_row1_col7" class="data row1 col7" >0.00 %</td>
#       <td id="T_911d6_row1_col8" class="data row1 col8" >0.00 %</td>
#       <td id="T_911d6_row1_col9" class="data row1 col9" >0.00 %</td>
#       <td id="T_911d6_row1_col10" class="data row1 col10" >0.00 %</td>
#       <td id="T_911d6_row1_col11" class="data row1 col11" >0.00 %</td>
#       <td id="T_911d6_row1_col12" class="data row1 col12" >0.00 %</td>
#       <td id="T_911d6_row1_col13" class="data row1 col13" >0.00 %</td>
#       <td id="T_911d6_row1_col14" class="data row1 col14" >0.00 %</td>
#       <td id="T_911d6_row1_col15" class="data row1 col15" >0.00 %</td>
#       <td id="T_911d6_row1_col16" class="data row1 col16" >0.00 %</td>
#       <td id="T_911d6_row1_col17" class="data row1 col17" >0.00 %</td>
#       <td id="T_911d6_row1_col18" class="data row1 col18" >0.00 %</td>
#       <td id="T_911d6_row1_col19" class="data row1 col19" >0.00 %</td>
#       <td id="T_911d6_row1_col20" class="data row1 col20" >0.00 %</td>
#       <td id="T_911d6_row1_col21" class="data row1 col21" >0.00 %</td>
#       <td id="T_911d6_row1_col22" class="data row1 col22" >0.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_911d6_level0_row2" class="row_heading level0 row2" >19</th>
#       <td id="T_911d6_row2_col0" class="data row2 col0" >1.42 %</td>
#       <td id="T_911d6_row2_col1" class="data row2 col1" >4.31 %</td>
#       <td id="T_911d6_row2_col2" class="data row2 col2" >3.49 %</td>
#       <td id="T_911d6_row2_col3" class="data row2 col3" >3.49 %</td>
#       <td id="T_911d6_row2_col4" class="data row2 col4" >3.49 %</td>
#       <td id="T_911d6_row2_col5" class="data row2 col5" >0.00 %</td>
#       <td id="T_911d6_row2_col6" class="data row2 col6" >0.00 %</td>
#       <td id="T_911d6_row2_col7" class="data row2 col7" >0.00 %</td>
#       <td id="T_911d6_row2_col8" class="data row2 col8" >0.00 %</td>
#       <td id="T_911d6_row2_col9" class="data row2 col9" >0.00 %</td>
#       <td id="T_911d6_row2_col10" class="data row2 col10" >0.00 %</td>
#       <td id="T_911d6_row2_col11" class="data row2 col11" >0.00 %</td>
#       <td id="T_911d6_row2_col12" class="data row2 col12" >0.00 %</td>
#       <td id="T_911d6_row2_col13" class="data row2 col13" >0.00 %</td>
#       <td id="T_911d6_row2_col14" class="data row2 col14" >0.00 %</td>
#       <td id="T_911d6_row2_col15" class="data row2 col15" >0.00 %</td>
#       <td id="T_911d6_row2_col16" class="data row2 col16" >0.00 %</td>
#       <td id="T_911d6_row2_col17" class="data row2 col17" >0.00 %</td>
#       <td id="T_911d6_row2_col18" class="data row2 col18" >0.00 %</td>
#       <td id="T_911d6_row2_col19" class="data row2 col19" >0.00 %</td>
#       <td id="T_911d6_row2_col20" class="data row2 col20" >0.00 %</td>
#       <td id="T_911d6_row2_col21" class="data row2 col21" >0.00 %</td>
#       <td id="T_911d6_row2_col22" class="data row2 col22" >0.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_911d6_level0_row3" class="row_heading level0 row3" >20</th>
#       <td id="T_911d6_row3_col0" class="data row3 col0" >0.63 %</td>
#       <td id="T_911d6_row3_col1" class="data row3 col1" >3.42 %</td>
#       <td id="T_911d6_row3_col2" class="data row3 col2" >2.82 %</td>
#       <td id="T_911d6_row3_col

# %% [markdown]
# #### Memory

# %%
(df
 .memory_usage(deep=True)
 .apply(lambda s: s / 1000000)
 .pipe(lambda df_: pd.concat([df_, df.dtypes], axis = 1))
 .rename(columns={0:'memory', 1:'dtype'})
)
# Out:
#                          memory    dtype
# Index                  0.000128      NaN
# genero                11.588742   object
# etnia                 11.604763   object
# cod_parroquia_reside   1.426016  float64
# cod_canton_reside      1.426016  float64
# cod_prov_reside        1.426016  float64
# pos_id                 1.426016    int64
# pos_nota               1.426016  float64
# pos_prioridad          1.426016  float64
# ies_id                 1.426016    int64
# nombre_institucion    18.691445   object
# provincia             11.591679   object
# canton                12.298591   object
# parroquia             16.768532   object
# car_id                 1.426016    int64
# carrera               15.168719   object
# area                  15.540280   object
# modalidad             11.867452   object
# acepta_cupo            1.426016    int64
# ofa_id                 1.426016    int64
# discapacidad          10.516868   object
# asa_beca               1.426016    int64
# cod_final              1.426016    int64
# periodo                1.426016    int64

# %% [markdown]
# ### Columns' names and Index

# %%
df_ = (df
 .rename(columns={'nombre_institucion':'ies_nombre',
                  'cod_prov_reside':'cod_provincia_reside',
                  'provincia':'provincia_ies', 'canton':'canton_ies', 
                  'parroquia':'parroquia_ies'})
)
# Out:
#            genero      etnia  cod_parroquia_reside  cod_canton_reside  \
# 0       MASCULINO    Mestizo               10113.0              101.0
# 1       MASCULINO  IndÃ­gena               60104.0              601.0
# 2       MASCULINO  Mestizo/a              170256.0             1702.0
# 3        FEMENINO  Mestizo/a              220350.0             2203.0
# 4        FEMENINO  Mestizo/a              170164.0             1701.0
# ...           ...        ...                   ...                ...
# 178247  MASCULINO    Mestizo              180108.0             1801.0
# 178248   FEMENINO  Mestizo/a               10158.0              101.0
# 178249   FEMENINO    Mestizo               91250.0              912.0
# 178250   FEMENINO        NaN                   NaN                NaN
# 178251   FEMENINO    Mestizo               70702.0              707.0
#
#         cod_provincia_reside    pos_id  pos_nota  pos_prioridad  ies_id  \
# 0                        1.0  16516144     784.0            1.0      48
# 1                        6.0  17825859     774.0            1.0      58
# 2                       17.0  25735501     759.0            1.0     804
# 3                       22.0  28452649     841.0            1.0     877
# 4                       17.0  24917400     760.0            2.0      46
# ...                      ...       ...       ...            ...     ...
# 178247                  18.0  14552460     883.0            1.0      82
# 178248                   1.0  24666557     801.0            1.0      44
# 178249                   9.0  19776456     802.0            1.0      59
# 178250                   NaN  21554719     807.0            1.0      89
# 178251                   7.0  19764029     909.0            1.0      85
#
#                                                ies_nombre  ... car_id  \
# 0                                   UNIVERSIDAD DE CUENCA  ...   4910
# 1                          UNIVERSIDAD ESTATAL DE BOLIVAR  ...   4908
# 2                    UNIVERSIDAD REGIONAL AMAZONICA IKIAM  ...   5335
# 3       INSTITUTO TECNOLÓGICO SUPERIOR GENERAL ELOY AL...  ...   7147
# 4                         UNIVERSIDAD CENTRAL DEL ECUADOR  ...   7363
# ...                                                   ...  ...    ...
# 178247                      UNIVERSIDAD TECNICA DE AMBATO  ...   4458
# 178248                     UNIVERSIDAD CATOLICA DE CUENCA  ...   5455
# 178249                     UNIVERSIDAD ESTATAL DE MILAGRO  ...   5474
# 178250             UNIVERSIDAD TECNICA ESTATAL DE QUEVEDO  ...   5316
# 178251                     UNIVERSIDAD TECNICA DE MACHALA  ...   4801
#
#                                       carrera  \
# 0                                GASTRONOMIA
# 1                              MERCADOTECNIA
# 2                               BIOTECNOLOGIA
# 3       TECNOLOGIA SUPERIOR EN ADMINISTRACION
# 4                             ARTES PLASTICAS
# ...                                       ...
# 178247              CONTABILIDAD Y AUDITORIA
# 178248             ADMINISTRACION DE EMPRESAS
# 178249                        TRABAJO SOCIAL
# 178250                               SOFTWARE
# 178251                     COMERCIO EXTERIOR
#
#                                                      area        modalidad  \
# 0                                               SERVICIOS       PRESENCIAL
# 1                                          ADMINISTRACION       PRESENCIAL
# 2           CIENCIAS NATURALES, MATEMATICAS Y ESTADISTICA       PRESENCIAL
# 3                                          ADMINISTRACION       PRESENCIAL
# 4                                     ARTES Y HUMANIDADES       PRESENCIAL
# ...                                                   ...              ...
# 178247                                     ADMINISTRACION       PRESENCIAL
# 178248                                     ADMINISTRACION       PRESENCIAL
# 178249  CIENCIAS SOCIALES, PERIODISMO, INFORMACION Y D...  SEMI-PRESENCIAL
# 178250  TECNOLOGIAS DE LA INFORMACION Y LA COMUNICACIO...       PRESENCIAL
# 178251                                     ADMINISTRACION       PRESENCIAL
#
#        acepta_cupo  ofa_id discapacidad  asa_beca   cod_final periodo
# 0                1   98329           NO         0  9352450110      18
# 1                1  103172           NO         0  2185420629      18
# 2                1  167503           NO         0  9250821701      21
# 3                1  177308           NO         0  2746992201      22
# 4                2  162934           NO         0  2520001738      21
# ...            ...     ...          ...       ...         ...     ...
# 178247           1   86623           NO         0  1860631810      17
# 178248           0  165935           NO         0  1486830138      21
# 178249           1  149370           NO         0  2097760665      19
# 178250           1  153898           NO         0  2090151229      20
# 178251           1  144968           NO         0  2432830738      19
#
# [178252 rows x 23 columns]

# %% [markdown]
# ### Numeric Types

# %%
_df = (df
 .drop(columns=['asa_beca']) # columns contains 0 only; uninformative
 .rename(columns={'nombre_institucion':'ies_nombre',
                  'cod_prov_reside':'cod_provincia_reside',
                  'provincia':'provincia_ies', 'canton':'canton_ies', 
                  'parroquia':'parroquia_ies'})
 .assign(acepta_cupo=lambda df_: (df_
                                  .acepta_cupo
                                  .replace(2, np.nan) # replacing meaningless 2 with np.nan
                                  .astype('uint8', errors='ignore')),
         **{c: lambda df_, c=c: df_[c].astype('uint8', errors='ignore') for c in ['periodo', 
                                                                                  'pos_prioridad', 
                                                                                  'cod_provincia_reside']},
         **{c: lambda df_, c=c: df_[c].astype('uint16', errors='ignore') for c in ['car_id', 
                                                                                   'pos_nota', 'ies_id',
                                                                                   'cod_canton_reside']},
         **{c: lambda df_, c=c: df_[c].astype('uint32', errors='ignore') for c in ['ofa_id', 'pos_id', 
                                                                                   'cod_parroquia_reside']},
         genero=lambda df_: df_.genero.replace({'MASCULINO':1, 'FEMENINO':0}).astype('uint8', errors='ignore'), # 1: Masculino ; 0: Femenino
         discapacidad=lambda df_: df_.discapacidad.replace({'NO':0, 'SI':1}).astype('uint8', errors='ignore')
         )
)

# %%
(_df
 .select_dtypes('number')
 .describe()
)
# Out:
#               genero  cod_parroquia_reside  cod_canton_reside  \
# count  175966.000000         168658.000000      168658.000000
# mean        0.442131         118652.677323        1186.284440
# std         0.496641          54021.272067         540.189535
# min         0.000000          10101.000000         101.000000
# 25%         0.000000          90112.000000         901.000000
# 50%         0.000000         110161.000000        1101.000000
# 75%         1.000000         170110.000000        1701.000000
# max         1.000000         900751.000000        9007.000000
#
#        cod_provincia_reside        pos_id       pos_nota  pos_prioridad  \
# count         168658.000000  1.782520e+05  178252.000000  178252.000000
# mean              11.826554  2.122624e+07     778.151101       1.756154
# std                5.407217  4.395719e+06      78.961527       1.124222
# min                1.000000  1.348796e+07     392.000000       1.000000
# 25%                9.000000  1.745816e+07     723.000000       1.000000
# 50%               11.000000  2.138317e+07     775.000000       1.000000
# 75%               17.000000  2.472318e+07     832.000000       2.000000
# max               90.000000  2.958155e+07    1000.000000       5.000000
#
#               ies_id         car_id    acepta_cupo         ofa_id  \
# count  178252.000000  178252.000000  174896.000000  178252.000000
# mean      175.639533    5470.455445       0.818086  140492.648649
# std       256.804393     965.909128       0.385775   33326.488826
# min        22.000000    4447.000000       0.000000   81359.000000
# 25%        51.000000    4748.000000       1.000000  100066.000000
# 50%        60.000000    5205.000000       1.000000  151373.000000
# 75%        92.000000    5476.000000       1.000000  167182.000000
# max      1054.000000    7603.000000       1.000000  183438.000000
#
#         discapacidad     cod_final        periodo
# count  178252.000000  1.782520e+05  178252.000000
# mean        0.007972  2.544334e+09      19.569278
# std         0.088929  1.552583e+09       1.692178
# min         0.000000  1.000011e+09      17.000000
# 25%         0.000000  1.896541e+09      18.000000
# 50%         0.000000  2.230116e+09      20.000000
# 75%         0.000000  2.544917e+09      21.000000
# max         1.000000  9.999981e+09      22.000000

# %% [markdown]
# ### Non Numeric Types

# %%
import json

with open('../utils.json') as f:
    dd = json.load(f)

_df = (df
 .drop(columns=['asa_beca']) # columns contains 0 only; uninformative
 .rename(columns={'nombre_institucion':'ies_nombre',
                  'cod_prov_reside':'cod_provincia_reside',
                  'provincia':'provincia_ies', 'canton':'canton_ies', 
                  'parroquia':'parroquia_ies'})
 .assign(acepta_cupo=lambda df_: (df_
                                  .acepta_cupo
                                  .replace(2, np.nan) # replacing meaningless 2 with np.nan
                                  .astype('uint8', errors='ignore')),
         etnia=lambda df_: (df_.etnia
                            .str.lower()
                            .replace(regex=dd['etnias'])
                            .str.title()
                            .replace(regex={'Ind...ena':'Indígena'})
                            .astype('category')),
         parroquia_ies=lambda df_: (df_
                                    .parroquia_ies
                                    .str.title()
                                    .replace({'Abraham Calazacã\x93N':'Abraham Calazacón',
                                              'Azogues' : 'Azogues, Cabecera Cantonal',
                                              'Bahã\x8dA De Carã\x81Quez': 'Bahía De Caráquez',
                                              'Baã\x91Os De Agua Santa' : 'Baños De Agua Santa',
                                              'Carcelã\x89N' : 'Carcelén', 'Caã\x91Ar' : 'Cañar',
                                              'Cariamanga' : 'Cariamanga, Cabecera Cantonal',
                                              'Cayambe' : 'Cayambe, Cabecera Cantonal',
                                              'El Ã\x81Ngel' : 'El Ángel', 'Iã\x91Aquito' : 'Iñaquito',
                                              'La Aurora (Satã\x89Lite)' : 'La Aurora (Satélite)',
                                              'La Concepciã\x93N' : 'La Concepción',
                                              'Portoviejo' : 'Portoviejo, Cabecera Cantonal Y Capital Provincial',
                                              'Quevedo' : 'Quevedo, Cabecera Cantonal',
                                              'Santa Elena' : 'Santa Elena, Cabecera Cantonal Y Capital Provincial'})
                                    .replace(['Atocha \x96 Ficoa', 'Atocha Â\x80\x93 Ficoa'], 'Atocha Ficoa')
                                    .replace(['Sangolqui, Cabecera Cantonal', 'Sangolquã\x8d'], 'Sangolquí')
                                    .replace(['Santo Domingo De Los Colorados','Santo Domingo De Los Colorados, Cabecera Cantonal'], 
                                             'Santo Domingo De Los Tsachilas, Cabecera Cantonal Y Capital Provincial')
                                    .replace(['Tulcan, Cabecera Cantonal', 'Tulcán', 'Tulcã\x81N'],
                                             'Tulcán, Cabecera Cantonal Y Capital Provincial')
                                    .astype('category')),
         **{c: lambda df_, c=c: df_[c].astype('uint8', errors='ignore') for c in ['periodo', 
                                                                                  'pos_prioridad', 
                                                                                  'cod_provincia_reside']},
         **{c: lambda df_, c=c: df_[c].astype('uint16', errors='ignore') for c in ['car_id', 
                                                                                   'pos_nota', 'ies_id',
                                                                                   'cod_canton_reside']},
         **{c: lambda df_, c=c: df_[c].astype('uint32', errors='ignore') for c in ['ofa_id', 'pos_id', 
                                                                                   'cod_parroquia_reside']},
         **{c: lambda df_, c=c: df_[c].str.title().astype('category') for c in ['ies_nombre', 'provincia_ies', 
                                                                                'canton_ies', 'carrera', 'area', 
                                                                                'modalidad']},
         genero=lambda df_: df_.genero.replace({'MASCULINO':1, 'FEMENINO':0}).astype('uint8', errors='ignore'), # 1: Masculino ; 0: Femenino
         discapacidad=lambda df_: df_.discapacidad.replace({'NO':0, 'SI':1}).astype('uint8', errors='ignore'),
         universidad=lambda df_: df_.ies_nombre.str.contains('Universidad'),
         in_capital=lambda df_: df_.parroquia_ies.str.contains('Capital')
         )
)

# %%
(_df
 .select_dtypes(exclude='number')
 .describe()
)
# Out:
#           etnia                      ies_nombre provincia_ies canton_ies  \
# count    171879                          178252        178252     178252
# unique        7                             399            24         81
# top     Mestizo  Universidad Estatal De Milagro        Guayas    Milagro
# freq     142883                           26731         52782      27236
#
#                      parroquia_ies  carrera  \
# count                       178252   178252
# unique                         106      747
# top     Milagro, Cabecera Cantonal  Turismo
# freq                         27236     4128
#
#                                         area   modalidad universidad  \
# count                                 178252      178252      178252
# unique                                    18           6           2
# top     Ingenieria, Industria Y Construccion  Presencial        True
# freq                                   34014      138679      132271
#
#        in_capital
# count      178252
# unique          2
# top          True
# freq        92722

# %% [markdown]
# ### Resulting Changes

# %% [markdown]
# #### Missing Values

# %%
(_df
 .isna()
 .groupby(df.periodo)
 .mean()
 .style
 .format(lambda fl: f'{fl * 100:.2f} %')
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b9a9f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >genero</th>
#       <th class="col_heading level0 col1" >etnia</th>
#       <th class="col_heading level0 col2" >cod_parroquia_reside</th>
#       <th class="col_heading level0 col3" >cod_canton_reside</th>
#       <th class="col_heading level0 col4" >cod_provincia_reside</th>
#       <th class="col_heading level0 col5" >pos_id</th>
#       <th class="col_heading level0 col6" >pos_nota</th>
#       <th class="col_heading level0 col7" >pos_prioridad</th>
#       <th class="col_heading level0 col8" >ies_id</th>
#       <th class="col_heading level0 col9" >ies_nombre</th>
#       <th class="col_heading level0 col10" >provincia_ies</th>
#       <th class="col_heading level0 col11" >canton_ies</th>
#       <th class="col_heading level0 col12" >parroquia_ies</th>
#       <th class="col_heading level0 col13" >car_id</th>
#       <th class="col_heading level0 col14" >carrera</th>
#       <th class="col_heading level0 col15" >area</th>
#       <th class="col_heading level0 col16" >modalidad</th>
#       <th class="col_heading level0 col17" >acepta_cupo</th>
#       <th class="col_heading level0 col18" >ofa_id</th>
#       <th class="col_heading level0 col19" >discapacidad</th>
#       <th class="col_heading level0 col20" >cod_final</th>
#       <th class="col_heading level0 col21" >periodo</th>
#       <th class="col_heading level0 col22" >universidad</th>
#       <th class="col_heading level0 col23" >in_capital</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >periodo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9a9f_level0_row0" class="row_heading level0 row0" >17</th>
#       <td id="T_b9a9f_row0_col0" class="data row0 col0" >2.99 %</td>
#       <td id="T_b9a9f_row0_col1" class="data row0 col1" >4.68 %</td>
#       <td id="T_b9a9f_row0_col2" class="data row0 col2" >3.41 %</td>
#       <td id="T_b9a9f_row0_col3" class="data row0 col3" >3.41 %</td>
#       <td id="T_b9a9f_row0_col4" class="data row0 col4" >3.41 %</td>
#       <td id="T_b9a9f_row0_col5" class="data row0 col5" >0.00 %</td>
#       <td id="T_b9a9f_row0_col6" class="data row0 col6" >0.00 %</td>
#       <td id="T_b9a9f_row0_col7" class="data row0 col7" >0.00 %</td>
#       <td id="T_b9a9f_row0_col8" class="data row0 col8" >0.00 %</td>
#       <td id="T_b9a9f_row0_col9" class="data row0 col9" >0.00 %</td>
#       <td id="T_b9a9f_row0_col10" class="data row0 col10" >0.00 %</td>
#       <td id="T_b9a9f_row0_col11" class="data row0 col11" >0.00 %</td>
#       <td id="T_b9a9f_row0_col12" class="data row0 col12" >0.00 %</td>
#       <td id="T_b9a9f_row0_col13" class="data row0 col13" >0.00 %</td>
#       <td id="T_b9a9f_row0_col14" class="data row0 col14" >0.00 %</td>
#       <td id="T_b9a9f_row0_col15" class="data row0 col15" >0.00 %</td>
#       <td id="T_b9a9f_row0_col16" class="data row0 col16" >0.00 %</td>
#       <td id="T_b9a9f_row0_col17" class="data row0 col17" >1.07 %</td>
#       <td id="T_b9a9f_row0_col18" class="data row0 col18" >0.00 %</td>
#       <td id="T_b9a9f_row0_col19" class="data row0 col19" >0.00 %</td>
#       <td id="T_b9a9f_row0_col20" class="data row0 col20" >0.00 %</td>
#       <td id="T_b9a9f_row0_col21" class="data row0 col21" >0.00 %</td>
#       <td id="T_b9a9f_row0_col22" class="data row0 col22" >0.00 %</td>
#       <td id="T_b9a9f_row0_col23" class="data row0 col23" >0.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_b9a9f_level0_row1" class="row_heading level0 row1" >18</th>
#       <td id="T_b9a9f_row1_col0" class="data row1 col0" >2.15 %</td>
#       <td id="T_b9a9f_row1_col1" class="data row1 col1" >4.58 %</td>
#       <td id="T_b9a9f_row1_col2" class="data row1 col2" >3.69 %</td>
#       <td id="T_b9a9f_row1_col3" class="data row1 col3" >3.69 %</td>
#       <td id="T_b9a9f_row1_col4" class="data row1 col4" >3.69 %</td>
#       <td id="T_b9a9f_row1_col5" class="data row1 col5" >0.00 %</td>
#       <td id="T_b9a9f_row1_col6" class="data row1 col6" >0.00 %</td>
#       <td id="T_b9a9f_row1_col7" class="data row1 col7" >0.00 %</td>
#       <td id="T_b9a9f_row1_col8" class="data row1 col8" >0.00 %</td>
#       <td id="T_b9a9f_row1_col9" class="data row1 col9" >0.00 %</td>
#       <td id="T_b9a9f_row1_col10" class="data row1 col10" >0.00 %</td>
#       <td id="T_b9a9f_row1_col11" class="data row1 col11" >0.00 %</td>
#       <td id="T_b9a9f_row1_col12" class="data row1 col12" >0.00 %</td>
#       <td id="T_b9a9f_row1_col13" class="data row1 col13" >0.00 %</td>
#       <td id="T_b9a9f_row1_col14" class="data row1 col14" >0.00 %</td>
#       <td id="T_b9a9f_row1_col15" class="data row1 col15" >0.00 %</td>
#       <td id="T_b9a9f_row1_col16" class="data row1 col16" >0.00 %</td>
#       <td id="T_b9a9f_row1_col17" class="data row1 col17" >2.06 %</td>
#       <td id="T_b9a9f_row1_col18" class="data row1 col18" >0.00 %</td>
#       <td id="T_b9a9f_row1_col19" class="data row1 col19" >0.00 %</td>
#       <td id="T_b9a9f_row1_col20" class="data row1 col20" >0.00 %</td>
#       <td id="T_b9a9f_row1_col21" class="data row1 col21" >0.00 %</td>
#       <td id="T_b9a9f_row1_col22" class="data row1 col22" >0.00 %</td>
#       <td id="T_b9a9f_row1_col23" class="data row1 col23" >0.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_b9a9f_level0_row2" class="row_heading level0 row2" >19</th>
#       <td id="T_b9a9f_row2_col0" class="data row2 col0" >1.42 %</td>
#       <td id="T_b9a9f_row2_col1" class="data row2 col1" >4.31 %</td>
#       <td id="T_b9a9f_row2_col2" class="data row2 col2" >3.49 %</td>
#       <td id="T_b9a9f_row2_col3" class="data row2 col3" >3.49 %</td>
#       <td id="T_b9a9f_row2_col4" class="data row2 col4" >3.49 %</td>
#       <td id="T_b9a9f_row2_col5" class="data row2 col5" >0.00 %</td>
#       <td id="T_b9a9f_row2_col6" class="data row2 col6" >0.00 %</td>
#       <td id="T_b9a9f_row2_col7" class="data row2 col7" >0.00 %</td>
#       <td id="T_b9a9f_row2_col8" class="data row2 col8" >0.00 %</td>
#       <td id="T_b9a9f_row2_col9" class="data row2 col9" >0.00 %</td>
#       <td id="T_b9a9f_row2_col10" class="data row2 col10" >0.00 %</td>
#       <td id="T_b9a9f_row2_col11" class="data row2 col11" >0.00 %</td>
#       <td id="T_b9a9f_row2_col12" class="data row2 col12" >0.00 %</td>
#       <td id="T_b9a9f_row2_col13" class="data row2 col13" >0.00 %</td>
#       <td id="T_b9a9f_row2_col14" class="data row2 col14" >0.00 %</td>
#       <td id="T_b9a9f_row2_col15" class="data row2 col15" >0.00 %</td>
#       <td id="T_b9a9f_row2_col16" class="data row2 col16" >0.00 %</td>
#       <td id="T_b9a9f_row2_col17" class="data row2 col17" >1.68 %</td>
#       <td id="T_b9a9f_row2_col18" class="data row2 col18" >0.00 %</td>
#       <td id="T_b9a9f_row2_col19" class="data row2 col19" >0.00 %</td>
#       <td id="T_b9a9f_row2_col20" class="data row2 col20" >0.00 %</td>
#       <td id="T_b9a9f_row2_col21" class="data row2 col21" >0.00 %</td>
#       <td id="T_b9a9f_row2_col22" class="data row2 col22" >0.00 %</td>
#       <td id="T_b9a9f_row2_col23" class="data row2 col23" >0.00 %</td>

# %% [markdown]
# #### Memory

# %%
(_df
 .memory_usage(deep=True)
 .apply(lambda s: s / 1000000)
 .pipe(lambda df_: pd.concat([df_, _df.dtypes], axis = 1))
 .rename(columns={0:'memory', 1:'dtype'})
)
# Out:
#                         memory     dtype
# Index                 0.000128       NaN
# genero                1.426016   float64
# etnia                 0.179029  category
# cod_parroquia_reside  1.426016   float64
# cod_canton_reside     1.426016   float64
# cod_provincia_reside  1.426016   float64
# pos_id                0.713008    uint32
# pos_nota              0.356504    uint16
# pos_prioridad         0.178252     uint8
# ies_id                0.356504    uint16
# ies_nombre            0.438732  category
# provincia_ies         0.180454  category
# canton_ies            0.185927  category
# parroquia_ies         0.191017  category
# car_id                0.356504    uint16
# carrera               0.448772  category
# area                  0.180685  category
# modalidad             0.178819  category
# acepta_cupo           1.426016   float64
# ofa_id                0.713008    uint32
# discapacidad          0.178252     uint8
# cod_final             1.426016     int64
# periodo               0.178252     uint8
# universidad           0.178252      bool
# in_capital            0.178252      bool

# %% [markdown]
# ### Tweak Asignaciones

# %%
import json

with open('../utils.json') as f:
    dd = json.load(f)

def tweak_asignaciones(df):
    return (df
     .drop(columns=['asa_beca']) # columns contains 0 only; uninformative
     .rename(columns={'nombre_institucion':'ies_nombre',
                      'cod_prov_reside':'cod_provincia_reside',
                      'provincia':'provincia_ies', 'canton':'canton_ies', 
                      'parroquia':'parroquia_ies'})
     .assign(acepta_cupo=lambda df_: (df_
                                      .acepta_cupo
                                      .replace(2, np.nan) # replacing meaningless 2 with np.nan
                                      .astype('uint8', errors='ignore')),
             etnia=lambda df_: (df_.etnia
                                .str.lower()
                                .replace(regex=dd['etnias'])
                                .str.title()
                                .replace(regex={'Ind...ena':'Indígena'})
                                .astype('category')),
             parroquia_ies=lambda df_: (df_
                                        .parroquia_ies
                                        .str.title()
                                        .replace({'Abraham Calazacã\x93N':'Abraham Calazacón',
                                                  'Azogues' : 'Azogues, Cabecera Cantonal',
                                                  'Bahã\x8dA De Carã\x81Quez': 'Bahía De Caráquez',
                                                  'Baã\x91Os De Agua Santa' : 'Baños De Agua Santa',
                                                  'Carcelã\x89N' : 'Carcelén', 'Caã\x91Ar' : 'Cañar',
                                                  'Cariamanga' : 'Cariamanga, Cabecera Cantonal',
                                                  'Cayambe' : 'Cayambe, Cabecera Cantonal',
                                                  'El Ã\x81Ngel' : 'El Ángel', 'Iã\x91Aquito' : 'Iñaquito',
                                                  'La Aurora (Satã\x89Lite)' : 'La Aurora (Satélite)',
                                                  'La Concepciã\x93N' : 'La Concepción',
                                                  'Portoviejo' : 'Portoviejo, Cabecera Cantonal Y Capital Provincial',
                                                  'Quevedo' : 'Quevedo, Cabecera Cantonal',
                                                  'Santa Elena' : 'Santa Elena, Cabecera Cantonal Y Capital Provincial'})
                                        .replace(['Atocha \x96 Ficoa', 'Atocha Â\x80\x93 Ficoa'], 'Atocha Ficoa')
                                        .replace(['Sangolqui, Cabecera Cantonal', 'Sangolquã\x8d'], 'Sangolquí')
                                        .replace(['Santo Domingo De Los Colorados','Santo Domingo De Los Colorados, Cabecera Cantonal'], 
                                                 'Santo Domingo De Los Tsachilas, Cabecera Cantonal Y Capital Provincial')
                                        .replace(['Tulcan, Cabecera Cantonal', 'Tulcán', 'Tulcã\x81N'],
                                                 'Tulcán, Cabecera Cantonal Y Capital Provincial')
                                        .astype('category')),
             **{c: lambda df_, c=c: df_[c].astype('uint8', errors='ignore') for c in ['periodo', 
                                                                                      'pos_prioridad', 
                                                                                      'cod_provincia_reside']},
             **{c: lambda df_, c=c: df_[c].astype('uint16', errors='ignore') for c in ['car_id', 
                                                                                       'pos_nota', 'ies_id',
                                                                                       'cod_canton_reside']},
             **{c: lambda df_, c=c: df_[c].astype('uint32', errors='ignore') for c in ['ofa_id', 'pos_id', 
                                                                                       'cod_parroquia_reside']},
             **{c: lambda df_, c=c: df_[c].str.title().astype('category') for c in ['ies_nombre', 'provincia_ies', 
                                                                                    'canton_ies', 'carrera', 'area', 
                                                                                    'modalidad']},
             genero=lambda df_: df_.genero.replace({'MASCULINO':1, 'FEMENINO':0}).astype('uint8', errors='ignore'), # 1: Masculino ; 0: Femenino
             discapacidad=lambda df_: df_.discapacidad.replace({'NO':0, 'SI':1}).astype('uint8', errors='ignore'),
             universidad=lambda df_: df_.ies_nombre.str.contains('Universidad'),
             in_capital=lambda df_: df_.parroquia_ies.str.contains('Capital')
             )
    )
