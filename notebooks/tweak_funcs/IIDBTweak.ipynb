# %%
import numpy as np
import pandas as pd
import json

idf = pd.read_csv('../../data/tt_inscripciones_samp.csv')

# %%
idf.head().T
# Out:
#                                          0                1                2  \
# usu_estado_civil                         S                S                S
# usu_fecha_nac            10/5/1998 0:00:00  09/04/2002 0:00  20/09/2002 0:00
# ins_sexo                             MUJER           HOMBRE            MUJER
# ins_fecha               25/4/2019 18:30:37  15/01/2021 1:03  17/01/2021 1:35
# pais_res                           ECUADOR          ECUADOR          ECUADOR
# cod_provincia_reside                  10.0              9.0              4.0
# cod_canton_reside                   1006.0            922.0            401.0
# cod_parroquia_reside              100650.0          92250.0          40102.0
# ins_autoidentificacion             MESTIZO       Montubio/a        Mestizo/a
# cod_final                     1416621074.0     2397810938.0     2548550429.0
# periodo                                 18               21               21
# escolar_no_escolar                     NaN              NaN              NaN
# internet_domicilio                     NaN               SI               SI
# computadora_domicilio                  NaN               NO               NO
#
#                                    3             4
# usu_estado_civil                   S             S
# usu_fecha_nac             12/06/1985    06/05/2002
# ins_sexo                       MUJER         MUJER
# ins_fecha                 07/12/2019    05/12/2019
# pais_res                     ECUADOR       ECUADOR
# cod_provincia_reside             9.0           9.0
# cod_canton_reside              901.0         919.0
# cod_parroquia_reside         90114.0       91953.0
# ins_autoidentificacion        MULATO      MONTUBIO
# cod_final               2362460974.0  2428020938.0
# periodo                           19            19
# escolar_no_escolar               NaN           NaN
# internet_domicilio               NaN           NaN
# computadora_domicilio            NaN           NaN

# %% [markdown]
# #### Duplicates

# %%
# No apparent duplicates in this subset
def get_shape(df):
    print(df.shape)
    return df

(idf
 .pipe(get_shape)
 .drop_duplicates()
 .pipe(get_shape)
 .sample()
)
# Out:
# (539535, 14)
# (539455, 14)
#        usu_estado_civil usu_fecha_nac ins_sexo ins_fecha pais_res  \
# 408900                S      3/4/2000   HOMBRE  1/3/2019  ECUADOR
#
#         cod_provincia_reside  cod_canton_reside  cod_parroquia_reside  \
# 408900                  13.0             1309.0              130902.0
#
#        ins_autoidentificacion     cod_final  periodo escolar_no_escolar  \
# 408900                MESTIZO  1.697051e+09       17                NaN
#
#        internet_domicilio computadora_domicilio
# 408900                NaN                   NaN

# %% [markdown]
# ### Understanding our data

# %% [markdown]
# #### Missing Values

# %%
(idf
 .isna()
 .groupby(idf.periodo)
 .mean()
 .style
 .format(lambda fl: f'{fl * 100:.2f} %')
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_35ff9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >usu_estado_civil</th>
#       <th class="col_heading level0 col1" >usu_fecha_nac</th>
#       <th class="col_heading level0 col2" >ins_sexo</th>
#       <th class="col_heading level0 col3" >ins_fecha</th>
#       <th class="col_heading level0 col4" >pais_res</th>
#       <th class="col_heading level0 col5" >cod_provincia_reside</th>
#       <th class="col_heading level0 col6" >cod_canton_reside</th>
#       <th class="col_heading level0 col7" >cod_parroquia_reside</th>
#       <th class="col_heading level0 col8" >ins_autoidentificacion</th>
#       <th class="col_heading level0 col9" >cod_final</th>
#       <th class="col_heading level0 col10" >periodo</th>
#       <th class="col_heading level0 col11" >escolar_no_escolar</th>
#       <th class="col_heading level0 col12" >internet_domicilio</th>
#       <th class="col_heading level0 col13" >computadora_domicilio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >periodo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35ff9_level0_row0" class="row_heading level0 row0" >17</th>
#       <td id="T_35ff9_row0_col0" class="data row0 col0" >0.40 %</td>
#       <td id="T_35ff9_row0_col1" class="data row0 col1" >0.37 %</td>
#       <td id="T_35ff9_row0_col2" class="data row0 col2" >0.00 %</td>
#       <td id="T_35ff9_row0_col3" class="data row0 col3" >0.00 %</td>
#       <td id="T_35ff9_row0_col4" class="data row0 col4" >9.32 %</td>
#       <td id="T_35ff9_row0_col5" class="data row0 col5" >2.56 %</td>
#       <td id="T_35ff9_row0_col6" class="data row0 col6" >2.56 %</td>
#       <td id="T_35ff9_row0_col7" class="data row0 col7" >2.56 %</td>
#       <td id="T_35ff9_row0_col8" class="data row0 col8" >14.24 %</td>
#       <td id="T_35ff9_row0_col9" class="data row0 col9" >0.00 %</td>
#       <td id="T_35ff9_row0_col10" class="data row0 col10" >0.00 %</td>
#       <td id="T_35ff9_row0_col11" class="data row0 col11" >100.00 %</td>
#       <td id="T_35ff9_row0_col12" class="data row0 col12" >100.00 %</td>
#       <td id="T_35ff9_row0_col13" class="data row0 col13" >100.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_35ff9_level0_row1" class="row_heading level0 row1" >18</th>
#       <td id="T_35ff9_row1_col0" class="data row1 col0" >0.03 %</td>
#       <td id="T_35ff9_row1_col1" class="data row1 col1" >0.03 %</td>
#       <td id="T_35ff9_row1_col2" class="data row1 col2" >0.00 %</td>
#       <td id="T_35ff9_row1_col3" class="data row1 col3" >0.00 %</td>
#       <td id="T_35ff9_row1_col4" class="data row1 col4" >2.46 %</td>
#       <td id="T_35ff9_row1_col5" class="data row1 col5" >2.46 %</td>
#       <td id="T_35ff9_row1_col6" class="data row1 col6" >2.46 %</td>
#       <td id="T_35ff9_row1_col7" class="data row1 col7" >2.46 %</td>
#       <td id="T_35ff9_row1_col8" class="data row1 col8" >3.55 %</td>
#       <td id="T_35ff9_row1_col9" class="data row1 col9" >0.00 %</td>
#       <td id="T_35ff9_row1_col10" class="data row1 col10" >0.00 %</td>
#       <td id="T_35ff9_row1_col11" class="data row1 col11" >100.00 %</td>
#       <td id="T_35ff9_row1_col12" class="data row1 col12" >100.00 %</td>
#       <td id="T_35ff9_row1_col13" class="data row1 col13" >100.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_35ff9_level0_row2" class="row_heading level0 row2" >19</th>
#       <td id="T_35ff9_row2_col0" class="data row2 col0" >0.07 %</td>
#       <td id="T_35ff9_row2_col1" class="data row2 col1" >0.00 %</td>
#       <td id="T_35ff9_row2_col2" class="data row2 col2" >1.62 %</td>
#       <td id="T_35ff9_row2_col3" class="data row2 col3" >0.00 %</td>
#       <td id="T_35ff9_row2_col4" class="data row2 col4" >1.76 %</td>
#       <td id="T_35ff9_row2_col5" class="data row2 col5" >1.76 %</td>
#       <td id="T_35ff9_row2_col6" class="data row2 col6" >1.76 %</td>
#       <td id="T_35ff9_row2_col7" class="data row2 col7" >1.76 %</td>
#       <td id="T_35ff9_row2_col8" class="data row2 col8" >2.54 %</td>
#       <td id="T_35ff9_row2_col9" class="data row2 col9" >0.00 %</td>
#       <td id="T_35ff9_row2_col10" class="data row2 col10" >0.00 %</td>
#       <td id="T_35ff9_row2_col11" class="data row2 col11" >100.00 %</td>
#       <td id="T_35ff9_row2_col12" class="data row2 col12" >100.00 %</td>
#       <td id="T_35ff9_row2_col13" class="data row2 col13" >100.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_35ff9_level0_row3" class="row_heading level0 row3" >20</th>
#       <td id="T_35ff9_row3_col0" class="data row3 col0" >0.13 %</td>
#       <td id="T_35ff9_row3_col1" class="data row3 col1" >0.05 %</td>
#       <td id="T_35ff9_row3_col2" class="data row3 col2" >0.00 %</td>
#       <td id="T_35ff9_row3_col3" class="data row3 col3" >0.00 %</td>
#       <td id="T_35ff9_row3_col4" class="data row3 col4" >1.42 %</td>
#       <td id="T_35ff9_row3_col5" class="data row3 col5" >1.42 %</td>
#       <td id="T_35ff9_row3_col6" class="data row3 col6" >1.42 %</td>
#       <td id="T_35ff9_row3_col7" class="data row3 col7" >1.42 %</td>
#       <td id="T_35ff9_row3_col8" class="data row3 col8" >1.37 %</td>
#       <td id="T_35ff9_row3_col9" class="data row3 col9" >0.00 %</td>
#       <td id="T_35ff9_row3_col10" class="data row3 col10" >0.00 %</td>
#       <td id="T_35ff9_row3_col11" class="data row3 col11" >100.00 %</td>
#       <td id="T_35ff9_row3_col12" class="data row3 col12" >1.49 %</td>
#       <td id="T_35ff9_row3_col13" class="data row3 col13" >1.49 %</td>
#     </tr>
#     <tr>
#       <th id="T_35ff9_level0_row4" class="row_heading level0 row4" >21</th>
#       <td id="T_35ff9_row4_col0" class="data row4 col0" >0.00 %</td>
#       <td id="T_35ff9_row4_col1" class="data row4 col1" >0.00 %</td>
#       <td id="T_35ff9_row4_col2" class="data row4 col2" >0.00 %</td>
#       <td id="T_35ff9_row4_col3" class="data row4 col3" >0.00 %</td>
#       <td id="T_35ff9_row4_col4" class="data row4 col4" >4.71 %</td>
#       <td id="T_35ff9_row4_col5" class="data row4 col5" >4.71 %</td>
#       <td id="T_35ff9_row4_col6" class="data row4 col6" >4.71 %</td>
#       <td id="T_35ff9_row4_col7" class="data row4 col7" >4.71 %</td>
#       <td id="T_35ff9_row4_col8" class="data row4 col8" >4.68 %</td>
#       <td id="T_35ff9_row4_col9" class="data row4 col9" >0.00 %</td>
#       <td id="T_35ff9_row4_col10" class="data row4 col10" >0.00 %</td>
#       <td id="T_35ff9_row4_col11" class="data row4 col11" >100.00 %</td>
#       <td id="T_35ff9_row4_col12" class="data row4 col12" >4.80 %</td>
#       <td id="T_35ff9_row4_col13" class="data row4 col13" >4.80 %</td>
#     </tr>
#     <tr>
#       <th id="T_35ff9_level0_row5" class="row_heading level0 row5" >22</th>
#       <td id="T_35ff9_row5_col0" class="data row5 col0" >0.00 %</td>
#       <td id="T_35ff9_row5_col1" class="data row5 col1" >0.00 %</td>
#       <td id="T_35ff9_row5_col2" class="data row5 col2" >0.00 %</td>
#       <td id="T_35ff9_row5_col3" class="data row5 col3" >0.00 %</td>
#       <td id="T_35ff9_row5_col4" class="data row5 col4" >3.83 %</td>
#       <td id="T_35ff9_row5_col5" class="data row5 col5" >3.83 %</td>
#       <td id="T_35ff9_row5_col6" class="data row5 col6" >3.83 %</td>
#       <td id="T_35ff9_row5_col7" class="data row5 col7" >3.83 %</td>
#       <td id="T_35ff9_row5_col8" class="data row5 col8" >3.79 %</td>
#       <td id="T_35ff9_row5_col9" class="data row5 col9" >0.00 %</td>
#       <td id="T_35ff9_row5_col10" class="data row5 col10" >0.00 %</td>
#       <td id="T_35ff9_row5_col11" class="data row5 col11" >4.28 %</td>
#       <td

# %% [markdown]
# #### Memory

# %%
(idf
 .memory_usage(deep=True)
 .apply(lambda s: s / 1000000)
 .pipe(lambda df_: pd.concat([df_, idf.dtypes], axis = 1))
 .rename(columns={0:'memory', 1:'dtype'})
)
# Out:
#                            memory    dtype
# Index                    0.000128      NaN
# usu_estado_civil        31.269266   object
# usu_fecha_nac           37.121401   object
# ins_sexo                33.766269   object
# ins_fecha               37.426809   object
# pais_res                33.633448   object
# cod_provincia_reside     4.316280  float64
# cod_canton_reside        4.316280  float64
# cod_parroquia_reside     4.316280  float64
# ins_autoidentificacion  34.454555   object
# cod_final                4.316280  float64
# periodo                  4.316280    int64
# escolar_no_escolar      19.650016   object
# internet_domicilio      22.580934   object
# computadora_domicilio   22.580934   object

# %% [markdown]
# ### Columns' names and Index

# %%
# drop one column, rename some, for now the df does not have any meaningful index
(idf
 .rename(columns={'usu_estado_civil': 'est_civil',
                  'usu_fecha_nac':'fec_naci',
                  'ins_sexo':'sexo',
                  'ins_fecha': 'fec_insc', # fecha de inscripcion
                  'ins_autoidentificacion': 'etnia'})
)
# Out:
#        est_civil            fec_naci    sexo            fec_insc pais_res  \
# 0              S   10/5/1998 0:00:00   MUJER  25/4/2019 18:30:37  ECUADOR
# 1              S     09/04/2002 0:00  HOMBRE     15/01/2021 1:03  ECUADOR
# 2              S     20/09/2002 0:00   MUJER     17/01/2021 1:35  ECUADOR
# 3              S          12/06/1985   MUJER          07/12/2019  ECUADOR
# 4              S          06/05/2002   MUJER          05/12/2019  ECUADOR
# ...          ...                 ...     ...                 ...      ...
# 539530         S     24/11/2002 0:00  HOMBRE    15/01/2021 15:37  ECUADOR
# 539531         S          13/02/2000  HOMBRE          02/12/2019  ECUADOR
# 539532         S             32756.0  HOMBRE           44047.943      NaN
# 539533         S  22/12/1987 0:00:00   MUJER   7/7/2021 21:26:15  ECUADOR
# 539534         S     25/09/2002 0:00   MUJER     15/01/2021 3:30  ECUADOR
#
#         cod_provincia_reside  cod_canton_reside  cod_parroquia_reside  \
# 0                       10.0             1006.0              100650.0
# 1                        9.0              922.0               92250.0
# 2                        4.0              401.0               40102.0
# 3                        9.0              901.0               90114.0
# 4                        9.0              919.0               91953.0
# ...                      ...                ...                   ...
# 539530                  17.0             1701.0              170121.0
# 539531                  23.0             2302.0              230250.0
# 539532                   NaN                NaN                   NaN
# 539533                   9.0              901.0               90114.0
# 539534                  12.0             1204.0              120450.0
#
#              etnia     cod_final  periodo escolar_no_escolar  \
# 0          MESTIZO  1.416621e+09       18                NaN
# 1       Montubio/a  2.397811e+09       21                NaN
# 2        Mestizo/a  2.548550e+09       21                NaN
# 3           MULATO  2.362461e+09       19                NaN
# 4         MONTUBIO  2.428021e+09       19                NaN
# ...            ...           ...      ...                ...
# 539530   Mestizo/a  2.503882e+09       21                NaN
# 539531     MESTIZO  1.762732e+09       19                NaN
# 539532         NaN  4.383500e+09       20                NaN
# 539533   Mestizo/a  8.594771e+09       22         No escolar
# 539534   Mestizo/a  2.602381e+09       21                NaN
#
#        internet_domicilio computadora_domicilio
# 0                     NaN                   NaN
# 1                      SI                    NO
# 2                      SI                    NO
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# ...                   ...                   ...
# 539530                 SI                    NO
# 539531                NaN                   NaN
# 539532                NaN                   NaN
# 539533                 SI                    SI
# 539534                 SI                    SI
#
# [539535 rows x 14 columns]

# %% [markdown]
# ### Dates

# %%
(idf
 .rename(columns={'usu_estado_civil': 'est_civil',
                  'usu_fecha_nac':'fec_naci',
                  'ins_sexo':'sexo',
                  'ins_fecha': 'fec_insc', # fecha de inscripcion
                  'ins_autoidentificacion': 'etnia'})
 .assign(fec_naci=lambda df_: (df_
                               .fec_naci
                               .mask(df_.periodo!=20,
                                     pd.to_datetime(df_.fec_naci, 
                                                    format = '%d/%m/%Y', 
                                                    errors='coerce', 
                                                    exact = False))
                               .mask(df_.periodo==20,
                                     pd.to_datetime(df_.fec_naci.where(df_.periodo==20, 45042).astype(float), # 45042 days have transpired since 1900-01-01
                                                    unit='d', 
                                                    origin='1900-01-01'))
                              ),
         fec_insc=lambda df_: (df_
                               .fec_insc
                               .mask(df_.periodo!=20,
                                     pd.to_datetime(df_
                                                    .fec_insc, 
                                                    format='%d/%m/%Y', 
                                                    errors='coerce', 
                                                    exact=False))
                               .mask(df_.periodo==20,
                                     pd.to_datetime(df_.fec_insc.where(df_.periodo==20, 45042).astype(float), 
                                                    unit='d', 
                                                    origin='1900-01-01'))
                              ))
)
# Out:
#        est_civil             fec_naci    sexo                    fec_insc  \
# 0              S  1998-05-10 00:00:00   MUJER         2019-04-25 00:00:00
# 1              S  2002-04-09 00:00:00  HOMBRE         2021-01-15 00:00:00
# 2              S  2002-09-20 00:00:00   MUJER         2021-01-17 00:00:00
# 3              S  1985-06-12 00:00:00   MUJER         2019-12-07 00:00:00
# 4              S  2002-05-06 00:00:00   MUJER         2019-12-05 00:00:00
# ...          ...                  ...     ...                         ...
# 539530         S  2002-11-24 00:00:00  HOMBRE         2021-01-15 00:00:00
# 539531         S  2000-02-13 00:00:00  HOMBRE         2019-12-02 00:00:00
# 539532         S  1989-09-07 00:00:00  HOMBRE  2020-08-06 22:37:55.200000
# 539533         S  1987-12-22 00:00:00   MUJER         2021-07-07 00:00:00
# 539534         S  2002-09-25 00:00:00   MUJER         2021-01-15 00:00:00
#
#        pais_res  cod_provincia_reside  cod_canton_reside  \
# 0       ECUADOR                  10.0             1006.0
# 1       ECUADOR                   9.0              922.0
# 2       ECUADOR                   4.0              401.0
# 3       ECUADOR                   9.0              901.0
# 4       ECUADOR                   9.0              919.0
# ...         ...                   ...                ...
# 539530  ECUADOR                  17.0             1701.0
# 539531  ECUADOR                  23.0             2302.0
# 539532      NaN                   NaN                NaN
# 539533  ECUADOR                   9.0              901.0
# 539534  ECUADOR                  12.0             1204.0
#
#         cod_parroquia_reside       etnia     cod_final  periodo  \
# 0                   100650.0     MESTIZO  1.416621e+09       18
# 1                    92250.0  Montubio/a  2.397811e+09       21
# 2                    40102.0   Mestizo/a  2.548550e+09       21
# 3                    90114.0      MULATO  2.362461e+09       19
# 4                    91953.0    MONTUBIO  2.428021e+09       19
# ...                      ...         ...           ...      ...
# 539530              170121.0   Mestizo/a  2.503882e+09       21
# 539531              230250.0     MESTIZO  1.762732e+09       19
# 539532                   NaN         NaN  4.383500e+09       20
# 539533               90114.0   Mestizo/a  8.594771e+09       22
# 539534              120450.0   Mestizo/a  2.602381e+09       21
#
#        escolar_no_escolar internet_domicilio computadora_domicilio
# 0                     NaN                NaN                   NaN
# 1                     NaN                 SI                    NO
# 2                     NaN                 SI                    NO
# 3                     NaN                NaN                   NaN
# 4                     NaN                NaN                   NaN
# ...                   ...                ...                   ...
# 539530                NaN                 SI                    NO
# 539531                NaN                NaN                   NaN
# 539532                NaN                NaN                   NaN
# 539533         No escolar                 SI                    SI
# 539534                NaN                 SI                    SI
#
# [539535 rows x 14 columns]

# %% [markdown]
# ### Numeric Types

# %%
_df = (idf
 .rename(columns={'usu_estado_civil': 'est_civil',
                  'usu_fecha_nac':'fec_naci',
                  'ins_sexo':'sexo',
                  'ins_fecha': 'fec_insc', # fecha de inscripcion
                  'ins_autoidentificacion': 'etnia'})      
 .assign(periodo=lambda df_: df_.periodo.astype('uint8'),
         **{c:lambda df_, c=c: df_[c].astype('uint32', errors='ignore') for c in ['cod_provincia_reside', 
                                                                 'cod_canton_reside', 
                                                                 'cod_parroquia_reside']},
         fec_naci=lambda df_: (df_
                               .fec_naci
                               .mask(df_.periodo!=20,
                                     pd.to_datetime(df_.fec_naci, 
                                                    format = '%d/%m/%Y', 
                                                    errors='coerce', 
                                                    exact = False))
                               .mask(df_.periodo==20,
                                     pd.to_datetime(df_.fec_naci.where(df_.periodo==20, 45042).astype(float),
                                                    unit='d', 
                                                    origin='1900-01-01'))
                               .pipe(lambda s: pd.to_datetime(s))
                              ),
         fec_insc=lambda df_: (df_
                               .fec_insc
                               .mask(df_.periodo!=20,
                                     pd.to_datetime(df_
                                                    .fec_insc, 
                                                    format='%d/%m/%Y', 
                                                    errors='coerce', 
                                                    exact=False))
                               .mask(df_.periodo==20,
                                     pd.to_datetime(df_.fec_insc.where(df_.periodo==20, 45042).astype(float), 
                                                    unit='d', 
                                                    origin='1900-01-01'))
                               .pipe(lambda s: pd.to_datetime(s))
                              ),
         edad=lambda df_: df_.fec_insc.dt.year - df_.fec_naci.dt.year,
         mes_insc=lambda df_: df_.fec_insc.dt.month)
)

# %%
(_df
 .select_dtypes('number')
 .describe()
)
# Out:
#        cod_provincia_reside  cod_canton_reside  cod_parroquia_reside  \
# count         524411.000000      524411.000000         524411.000000
# mean              11.738966        1177.367445         117761.459683
# std                5.571639         556.623602          55664.390839
# min                1.000000         101.000000          10101.000000
# 25%                9.000000         901.000000          90110.000000
# 50%               10.000000        1004.000000         100455.000000
# 75%               17.000000        1701.000000         170110.000000
# max               90.000000        9007.000000         900751.000000
#
#           cod_final        periodo           edad       mes_insc
# count  5.244110e+05  524411.000000  523714.000000  524411.000000
# mean  -2.220959e+08      18.950072      21.919800       6.466207
# std    1.929279e+09       1.845916       5.956129       3.913565
# min   -2.147484e+09      17.000000       0.000000       1.000000
# 25%   -2.147484e+09      17.000000      18.000000       3.000000
# 50%    1.021412e+09      19.000000      20.000000       7.000000
# 75%    1.741771e+09      21.000000      23.000000      11.000000
# max    2.147482e+09      22.000000      85.000000      12.000000

# %% [markdown]
# ### Non Numeric Types

# %%
with open('../../utils.json') as f:
    dd = json.load(f)

_df = (idf
 .rename(columns={'usu_estado_civil': 'est_civil',
                  'usu_fecha_nac':'fec_naci',
                  'ins_sexo':'sexo',
                  'ins_fecha': 'fec_insc', # fecha de inscripcion
                  'ins_autoidentificacion': 'etnia'})      
 .assign(periodo=lambda df_: df_.periodo.astype('uint8'),
         **{c:lambda df_, c=c: df_[c].astype('uint32', errors='ignore') for c in ['cod_provincia_reside', 
                                                                 'cod_canton_reside', 
                                                                 'cod_parroquia_reside']},
         sexo=lambda df_: df_.sexo.replace({'SIN DATO': np.nan}).str.title().astype('category'),
         pais_res=lambda df_: df_.pais_res.str.title().astype('category'),
         etnia=lambda df_: df_.etnia.str.lower().replace(regex=dd['etnias']).str.title().astype('category'),
         escolar_no_escolar=lambda df_: df_.escolar_no_escolar.astype('category'),
         **{c:lambda df_, c=c: df_[c].astype('category') for c in ['est_civil', 'internet_domicilio', 
                                                                   'computadora_domicilio']},
         fec_naci=lambda df_: (df_
                               .fec_naci
                               .mask(df_.periodo!=20,
                                     pd.to_datetime(df_.fec_naci, 
                                                    format = '%d/%m/%Y', 
                                                    errors='coerce', 
                                                    exact = False))
                               .mask(df_.periodo==20,
                                     pd.to_datetime(df_.fec_naci.where(df_.periodo==20, 45042).astype(float),
                                                    unit='d', 
                                                    origin='1900-01-01'))
                               .pipe(lambda s: pd.to_datetime(s))
                              ),
         fec_insc=lambda df_: (df_
                               .fec_insc
                               .mask(df_.periodo!=20,
                                     pd.to_datetime(df_
                                                    .fec_insc, 
                                                    format='%d/%m/%Y', 
                                                    errors='coerce', 
                                                    exact=False))
                               .mask(df_.periodo==20,
                                     pd.to_datetime(df_.fec_insc.where(df_.periodo==20, 45042).astype(float), 
                                                    unit='d', 
                                                    origin='1900-01-01'))
                               .pipe(lambda s: pd.to_datetime(s))
                              ),
         edad=lambda df_: (df_.fec_insc.dt.year - df_.fec_naci.dt.year).astype('uint16', errors='ignore'),
         mes_insc=lambda df_: (df_.fec_insc.dt.month.astype('category')
                                   .cat.add_categories([2, 6, 9, 10])
                                   .cat.reorder_categories(list(range(1, 13)), 
                                                           ordered=True)))
)

# %%
(_df
 .select_dtypes('category')
 .describe()
)
# Out:
#        est_civil    sexo pais_res    etnia escolar_no_escolar  \
# count     523555  486565   511491   500577              66749
# unique         5       2        4        7                  2
# top            S   Mujer  Ecuador  Mestizo         No escolar
# freq      478930  261299   511480   415913              53211
#
#        internet_domicilio computadora_domicilio
# count              196760                196760
# unique                  2                     2
# top                    SI                    SI
# freq               179668                161101

# %% [markdown]
# ### Resulting Changes

# %% [markdown]
# #### Missing Values

# %%
(_df
 .isna()
 .groupby(_df.periodo)
 .mean()
 .style
 .format(lambda fl: f'{fl * 100:.2f} %')
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6301c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6301c_level0_col0" class="col_heading level0 col0" >est_civil</th>
#       <th id="T_6301c_level0_col1" class="col_heading level0 col1" >fec_naci</th>
#       <th id="T_6301c_level0_col2" class="col_heading level0 col2" >sexo</th>
#       <th id="T_6301c_level0_col3" class="col_heading level0 col3" >fec_insc</th>
#       <th id="T_6301c_level0_col4" class="col_heading level0 col4" >pais_res</th>
#       <th id="T_6301c_level0_col5" class="col_heading level0 col5" >cod_provincia_reside</th>
#       <th id="T_6301c_level0_col6" class="col_heading level0 col6" >cod_canton_reside</th>
#       <th id="T_6301c_level0_col7" class="col_heading level0 col7" >cod_parroquia_reside</th>
#       <th id="T_6301c_level0_col8" class="col_heading level0 col8" >etnia</th>
#       <th id="T_6301c_level0_col9" class="col_heading level0 col9" >cod_final</th>
#       <th id="T_6301c_level0_col10" class="col_heading level0 col10" >periodo</th>
#       <th id="T_6301c_level0_col11" class="col_heading level0 col11" >escolar_no_escolar</th>
#       <th id="T_6301c_level0_col12" class="col_heading level0 col12" >internet_domicilio</th>
#       <th id="T_6301c_level0_col13" class="col_heading level0 col13" >computadora_domicilio</th>
#       <th id="T_6301c_level0_col14" class="col_heading level0 col14" >edad</th>
#       <th id="T_6301c_level0_col15" class="col_heading level0 col15" >mes_insc</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >periodo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6301c_level0_row0" class="row_heading level0 row0" >17</th>
#       <td id="T_6301c_row0_col0" class="data row0 col0" >0.40 %</td>
#       <td id="T_6301c_row0_col1" class="data row0 col1" >0.37 %</td>
#       <td id="T_6301c_row0_col2" class="data row0 col2" >20.86 %</td>
#       <td id="T_6301c_row0_col3" class="data row0 col3" >0.00 %</td>
#       <td id="T_6301c_row0_col4" class="data row0 col4" >9.32 %</td>
#       <td id="T_6301c_row0_col5" class="data row0 col5" >2.56 %</td>
#       <td id="T_6301c_row0_col6" class="data row0 col6" >2.56 %</td>
#       <td id="T_6301c_row0_col7" class="data row0 col7" >2.56 %</td>
#       <td id="T_6301c_row0_col8" class="data row0 col8" >14.24 %</td>
#       <td id="T_6301c_row0_col9" class="data row0 col9" >0.00 %</td>
#       <td id="T_6301c_row0_col10" class="data row0 col10" >0.00 %</td>
#       <td id="T_6301c_row0_col11" class="data row0 col11" >100.00 %</td>
#       <td id="T_6301c_row0_col12" class="data row0 col12" >100.00 %</td>
#       <td id="T_6301c_row0_col13" class="data row0 col13" >100.00 %</td>
#       <td id="T_6301c_row0_col14" class="data row0 col14" >0.37 %</td>
#       <td id="T_6301c_row0_col15" class="data row0 col15" >0.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_6301c_level0_row1" class="row_heading level0 row1" >18</th>
#       <td id="T_6301c_row1_col0" class="data row1 col0" >0.03 %</td>
#       <td id="T_6301c_row1_col1" class="data row1 col1" >0.03 %</td>
#       <td id="T_6301c_row1_col2" class="data row1 col2" >1.34 %</td>
#       <td id="T_6301c_row1_col3" class="data row1 col3" >0.00 %</td>
#       <td id="T_6301c_row1_col4" class="data row1 col4" >2.46 %</td>
#       <td id="T_6301c_row1_col5" class="data row1 col5" >2.46 %</td>
#       <td id="T_6301c_row1_col6" class="data row1 col6" >2.46 %</td>
#       <td id="T_6301c_row1_col7" class="data row1 col7" >2.46 %</td>
#       <td id="T_6301c_row1_col8" class="data row1 col8" >3.55 %</td>
#       <td id="T_6301c_row1_col9" class="data row1 col9" >0.00 %</td>
#       <td id="T_6301c_row1_col10" class="data row1 col10" >0.00 %</td>
#       <td id="T_6301c_row1_col11" class="data row1 col11" >100.00 %</td>
#       <td id="T_6301c_row1_col12" class="data row1 col12" >100.00 %</td>
#       <td id="T_6301c_row1_col13" class="data row1 col13" >100.00 %</td>
#       <td id="T_6301c_row1_col14" class="data row1 col14" >0.03 %</td>
#       <td id="T_6301c_row1_col15" class="data row1 col15" >0.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_6301c_level0_row2" class="row_heading level0 row2" >19</th>
#       <td id="T_6301c_row2_col0" class="data row2 col0" >0.07 %</td>
#       <td id="T_6301c_row2_col1" class="data row2 col1" >0.00 %</td>
#       <td id="T_6301c_row2_col2" class="data row2 col2" >1.62 %</td>
#       <td id="T_6301c_row2_col3" class="data row2 col3" >0.00 %</td>
#       <td id="T_6301c_row2_col4" class="data row2 col4" >1.76 %</td>
#       <td id="T_6301c_row2_col5" class="data row2 col5" >1.76 %</td>
#       <td id="T_6301c_row2_col6" class="data row2 col6" >1.76 %</td>
#       <td id="T_6301c_row2_col7" class="data row2 col7" >1.76 %</td>
#       <td id="T_6301c_row2_col8" class="data row2 col8" >2.54 %</td>
#       <td id="T_6301c_row2_col9" class="data row2 col9" >0.00 %</td>
#       <td id="T_6301c_row2_col10" class="data row2 col10" >0.00 %</td>
#       <td id="T_6301c_row2_col11" class="data row2 col11" >100.00 %</td>
#       <td id="T_6301c_row2_col12" class="data row2 col12" >100.00 %</td>
#       <td id="T_6301c_row2_col13" class="data row2 col13" >100.00 %</td>
#       <td id="T_6301c_row2_col14" class="data row2 col14" >0.00 %</td>
#       <td id="T_6301c_row2_col15" class="data row2 col15" >0.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_6301c_level0_row3" class="row_heading level0 row3" >20</th>
#       <td id="T_6301c_row3_col0" class="data row3 col0" >0.13 %</td>
#       <td id="T_6301c_row3_col1" class="data row3 col1" >0.05 %</td>
#       <td id="T_6301c_row3_col2" class="data row3 col2" >0.00 %</td>
#       <td id="T_6301c_row3_col3" class="data row3 col3" >0.00 %</td>
#       <td id="T_6301c_row3_col4" class="data row3 col4" >1.42 %</td>
#       <td id="T_6301c_row3_col5" class="data row3 col5" >1.42 %</td>
#       <td id="T_6301c_row3_col6" class="data row3 col6" >1.42 %</td>
#       <td id="T_6301c_row3_col7" class="data row3 col7" >1.42 %</td>
#       <td id="T_6301c_row3_col8" class="data row3 col8" >1.37 %</td>
#       <td id="T_6301c_row3_col9" class="data row3 col9" >0.00 %</td>
#       <td id="T_6301c_row3_col10" class="data row3 col10" >0.00 %</td>
#       <td id="T_6301c_row3_col11" class="data row3 col11" >100.00 %</td>
#       <td id="T_6301c_row3_col12" class="data row3 col12" >1.49 %</td>
#       <td id="T_6301c_row3_col13" class="data row3 col13" >1.49 %</td>
#       <td id="T_6301c_row3_col14" class="data row3 col14" >0.05 %</td>
#       <td id="T_6301c_row3_col15" class="data row3 col15" >0.00 %</td>
#     </tr>
#     <tr>
#       <th id="T_6301c_level0_row4" class="row_heading level0 row4" >21</th>
#       <td id="T_6301c_row4_col0" class="data row4 col0" >0.00 %</td>
#       <td id="T_6301c_row4_col1" class="data row4 col1" >0.00 %</td>
#       <td id="T_6301c_row4_col2" class="data row4 col2" >0.00 %</td>
#       <td id="T_6301c_row4_col3" class="data row4 col3" >0.00 %</td>
#       <td id="T_6301c_row4_col4" class="data row4 col4" >4.71 %</td>
#       <td id="T_6301c_row4_col5" class="data row4 col5" >4.71 %</td>
#       <td id="T_6301c_row4_col6" class="data row4 col6" >4.71 %</td>
#       <td id="T_6301c_row4_col7" class="data row4 col7" >4.71 %</td>
#       <td id="T_6301c_row4_col8" class="data row4 col8" >4.68 %</td>
#       <td id="T_6301c_row4_col9" class="data row4 col9" >0.00 %</td>
#       <td id="T_6301c_row4_col10" class="data row4 col10" >0.00 %</td>
#       <td id=

# %% [markdown]
# #### Memory

# %%
(_df
 .memory_usage(deep=True)
 .apply(lambda s: s / 1000000)
 .pipe(lambda df_: pd.concat([df_, _df.dtypes], axis = 1))
 .rename(columns={0:'memory', 1:'dtype'})
)
# Out:
#                          memory           dtype
# Index                  0.000128             NaN
# est_civil              0.539997        category
# fec_naci               4.316280  datetime64[ns]
# sexo                   0.539768        category
# fec_insc               4.316280  datetime64[ns]
# pais_res               0.540316        category
# cod_provincia_reside   4.316280         float64
# cod_canton_reside      4.316280         float64
# cod_parroquia_reside   4.316280         float64
# etnia                  0.540312        category
# cod_final              4.316280         float64
# periodo                0.539535           uint8
# escolar_no_escolar     0.539774        category
# internet_domicilio     0.539761        category
# computadora_domicilio  0.539761        category
# edad                   4.316280         float64
# mes_insc               0.539931        category

# %% [markdown]
# ### Tweak Inscripciones

# %%
with open('../utils.json') as f:
    dd = json.load(f)

def tweak_inscripciones(df):
    """
    
    Parameters:
    ----------
    `pd.DataFrame`: an instance of pd.DataFrame with the raw contents of the table 'inscripciones'
    """
    return (df
     .rename(columns={'usu_estado_civil': 'est_civil',
                      'usu_fecha_nac':'fec_naci',
                      'ins_sexo':'sexo',
                      'ins_fecha': 'fec_insc', # fecha de inscripcion
                      'ins_autoidentificacion': 'etnia'})       
     .assign(periodo=lambda df_: df_.periodo.astype('uint8'),
             **{c:lambda df_, c=c: df_[c].astype('uint32', errors='ignore') for c in ['cod_provincia_reside', 
                                                                                      'cod_canton_reside', 
                                                                                      'cod_parroquia_reside']},
             sexo=lambda df_: df_.sexo.replace({'SIN DATO': np.nan}).str.title().astype('category'),
             pais_res=lambda df_: df_.pais_res.str.title().astype('category'),
             etnia=lambda df_: df_.etnia.str.lower().replace(regex=dd['etnias']).str.title().astype('category'),
             escolar_no_escolar=lambda df_: df_.escolar_no_escolar.astype('category'),
             **{c:lambda df_, c=c: df_[c].astype('category') for c in ['est_civil', 'internet_domicilio', 
                                                                       'computadora_domicilio']},
             fec_naci=lambda df_: (df_
                                   .fec_naci
                                   .mask(df_.periodo!=20,
                                         pd.to_datetime(df_.fec_naci, 
                                                        format = '%d/%m/%Y', 
                                                        errors='coerce', 
                                                        exact = False))
                                   .mask(df_.periodo==20,
                                         pd.to_datetime(df_.fec_naci.where(df_.periodo==20, 45042).astype(float),
                                                        unit='d', 
                                                        origin='1900-01-01'))
                                   .pipe(lambda s: pd.to_datetime(s))
                                  ),
             fec_insc=lambda df_: (df_
                                   .fec_insc
                                   .mask(df_.periodo!=20,
                                         pd.to_datetime(df_
                                                        .fec_insc, 
                                                        format='%d/%m/%Y', 
                                                        errors='coerce', 
                                                        exact=False))
                                   .mask(df_.periodo==20,
                                         pd.to_datetime(df_.fec_insc.where(df_.periodo==20, 45042).astype(float), 
                                                        unit='d', 
                                                        origin='1900-01-01'))
                                   .pipe(lambda s: pd.to_datetime(s))
                                  ),
             edad=lambda df_: df_.fec_insc.dt.year - df_.fec_naci.dt.year,
             mes_insc=lambda df_: (df_.fec_insc.dt.month.astype('category')
                                   .cat.add_categories([2, 6, 9, 10])
                                   .cat.reorder_categories(list(range(1, 13)), 
                                                           ordered=True)))
    )
